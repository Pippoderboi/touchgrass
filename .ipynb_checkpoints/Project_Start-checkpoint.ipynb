# %%
# Project Start Date: 2025-06
from turtle import color
import geopandas as gpd
import pandas as pd
import os 
import folium 
from folium.plugins import MarkerCluster
from formatting_openhour import format_opening_hours

# %%
#defining original directory
original_dir = os.getcwd()

# %%
#choosing directory 
os.chdir('raw_data_geojson')

# %% [markdown]
# Create a map using folium

# %%
muenster = folium.Map(location=[51.96, 7.62], zoom_start=12.5)

# %% [markdown]
# function to create a feature group with clustering

# %%
def create_clustered_feature_group(name, min_zoom=13, show=True):
    fg = folium.FeatureGroup(name=name, show=show)
    return MarkerCluster(
        name=name,
        options={
            'maxClusterRadius': 80,  # Adjust cluster size
            'disableClusteringAtZoom': min_zoom,  # Start showing individual markers at this zoom
            'spiderfyDistanceMultiplier': 2  # How far markers spread out when clicked
        }
    ).add_to(fg), fg

# %% [markdown]
# Creating clustered feature groups
# Min_zoom here defines when markers

# %%
museen_cluster, museen_group = create_clustered_feature_group('Museen', min_zoom=20)
buechereien_cluster, buechereien_group = create_clustered_feature_group('Büchereien',min_zoom=20)
sportstaetten_cluster, sportstaetten_group = create_clustered_feature_group('Sportstätten',min_zoom=20)
tischtennis_cluster, tischtennis_group = create_clustered_feature_group('Tischtennisplatten',min_zoom=20)
wickelplaetze_cluster, wickelplaetze_group = create_clustered_feature_group('Wickelplätze',min_zoom=20)
give_boxen_cluster, give_boxen_group = create_clustered_feature_group('Give Boxen',min_zoom=20)
kinos_cluster, kinos_group = create_clustered_feature_group('Kinos',min_zoom=20)
kinder_cluster, kinder_group = create_clustered_feature_group('Spielplätze',min_zoom=20)
friedhof_cluster, friedhof_group = create_clustered_feature_group('Friedhöfe',min_zoom=20)
refill_cluster, refill_group = create_clustered_feature_group('Refillstationen',min_zoom=20)
gastro_cluster, gastro_group = create_clustered_feature_group('Gastronomie',min_zoom=20)
toiletten_cluster, toiletten_group = create_clustered_feature_group('Toiletten',min_zoom=20)
baeder_cluster, baeder_group = create_clustered_feature_group('Bäder',min_zoom=20)
theater_cluster, theater_group = create_clustered_feature_group('Theater',min_zoom=20)
gruenflaechen_cluster, gruenflaechen_group = create_clustered_feature_group('Grünflächen',min_zoom=14)

# %%
# Add Tischtennisplatten 
tischtennis=gpd.read_file('tischtennisplatten_muenster.geojson')
columns_to_show = ['ort','material']
for idx, row in tischtennis.iterrows():
    if row.geometry:
        lon, lat= row.geometry.x, row.geometry.y
        popup_text = "<br>".join(
            f"<b>{col.title()}:</b> {row[col]}" # Change of titles  
                for col in columns_to_show 
                if col in tischtennis.columns and pd.notnull(row[col])
        )
        folium.Marker(
            location=[lat,lon],
            popup=folium.Popup(popup_text, max_width=300),
            icon=folium.Icon(color='pink', icon='table-tennis', prefix='fa')
        ).add_to(tischtennis_cluster)

# %% [markdown]
# Add Museen

# %%
museen = gpd.read_file('museen_mit_opening_hours.geojson')
for idx, row in museen.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        popup_text = f"<strong>{row['NAME']}</strong><br>" \
                    f"Adresse: {row['STR_NAME']} {row['HSNR']}<br>" \
                    f"PLZ: {int(row['PLZ'])}<br>"
        
        # Add opening hours if available
        if 'opening_hours_osm' in row and pd.notna(row['opening_hours_osm']) and row['opening_hours_osm'] != 'null':
            formatted_hours = format_opening_hours(row['opening_hours_osm'])
            popup_text += f"Öffnungszeiten: {formatted_hours}<br>"
        else:
            popup_text += "Keine Öffnungszeiten verfügbar<br>"
            
        popup_text += f"Homepage: <a href='{row['HOMEPAGE']}' target='_blank'>{row['HOMEPAGE']}</a>"
        
        folium.Marker(
            location=[lat, lon],
            popup=popup_text,
            icon=folium.Icon(color='purple', icon='museum', prefix='fa')
        ).add_to(museen_cluster)
# Out:
# Before cleanup - days_part: 'Wed-Fri:' | times_part: '13:30-18:00'
# Before cleanup - days_part: 'Sat-Sun' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Sun' | times_part: '13:00-17:00'
# Before cleanup - days_part: 'Tue-Sun' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-20:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-13:00'
# Before cleanup - days_part: 'every 3. Sonntag von 16:30 -' | times_part: '19:00'
# Before cleanup - days_part: 'Sun' | times_part: '11:00-12:30'
# Before cleanup - days_part: 'Wed-Thu' | times_part: '18:00-21:00'
# Before cleanup - days_part: 'Sat-Sun' | times_part: '14:00-17:00'
# Before cleanup - days_part: 'Mon' | times_part: '18:00-21:00'
# Before cleanup - days_part: 'Tue-Sun' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Tue-Sun' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Sun' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon-Sun' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Sun' | times_part: '15:00-17:00'

# %%
# Add Buechereien
buechereien = gpd.read_file('buechereien_mit_opening_hours.geojson')
for idx, row in buechereien.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        popup_text = f"<strong>{row['NAME']}</strong><br>" \
                    f"Telefon: {row['TEL']}<br>" \
                    f"Öffnungszeiten: {format_opening_hours(row.get('OPENING HOURS'))}<br>" \
                    f"Homepage: <a href='{row['LINK1']}' target='_blank'>{row['LINK1']}</a>"
        folium.Marker(
            location=[lat, lon],
            popup=popup_text,
            icon=folium.Icon(color='orange', icon='book', prefix='fa')
        ).add_to(buechereien_cluster)
# Out:
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: '07' | times_part: '00-19:00'
# Before cleanup - days_part: 'sunset+ closed' | times_part: ''
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'

# %% [markdown]
# Add Sportstaetten

# %%
sportstaetten = gpd.read_file('sportstaetten_mit_opening_hours.geojson')

# %%
for idx, row in sportstaetten.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        hsnr = int(row['Hsnr']) if pd.notna(row['Hsnr']) else ''
        popup_text = f"<strong>{row['Produkt']}</strong><br>" \
                    f"Typ: {row['Teilprodukt']}<br>" \
                    f"Adresse: {row['Strname']} {hsnr}<br>" \
                    f"PLZ: {int(row['Plz'])}"
        
        # Add opening hours if available
        if 'OPENING HOURS' in row and pd.notna(row['OPENING HOURS']):
            formatted_hours = format_opening_hours(row['OPENING HOURS'])
            popup_text += f"<br>Öffnungszeiten: {formatted_hours}"
        
        icon = folium.Icon(color='red', icon='flag', prefix='fa')

        folium.Marker(
            location=[lat, lon],
            popup=popup_text,
            icon=folium.Icon (color='red',icon='basketball-ball',prefix='fa')
        ).add_to(sportstaetten_cluster)
# Out:
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'sunset-sunrise' | times_part: ''
# Before cleanup - days_part: 'sunset-sunrise' | times_part: ''
# Before cleanup - days_part: 'sunset-sunrise' | times_part: ''
# Before cleanup - days_part: 'sunset-sunrise' | times_part: ''
# Before cleanup - days_part: 'Su-Sat' | times_part: '00:00-24:00'
# Before cleanup - days_part: 'Mon-Sat 08:00-13:00, Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '05:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-00:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '05:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-00:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon,Th,Fri' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'Tu' | times_part: '12:00-02:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Sat off' | times_part: ''
# Before cleanup - days_part: 'Tu-Th' | times_part: '07:00-10:00,16:00-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '07:00-10:00,15:00-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '14:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Fri 08:30-13:00,' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Fri 08:30-13:00,' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-13:00,14:30-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-13:00,14:30-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-13:00,14:30-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: '07' | times_part: '00-19:00'
# Before cleanup - days_part: 'sunset+ closed' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '08:00-12:00,15:00-19:00'
# Before cleanup - days_part: 'We,Fri' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '08:00-12:00,15:00-19:00'
# Before cleanup - days_part: 'We,Fri' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '08:00-12:00,15:00-19:00'
# Before cleanup - days_part: 'We,Fri' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '08:00-12:00,15:00-19:00'
# Before cleanup - days_part: 'We,Fri' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '08:00-12:00,15:00-19:00'
# Before cleanup - days_part: 'We,Fri' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '08:00-12:00,15:00-19:00'
# Before cleanup - days_part: 'We,Fri' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '19:30-01:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '19:30-01:00'
# Before cleanup - days_part: 'We-Su' | times_part: '18:00+'
# Before cleanup - days_part: 'We-Su' | times_part: '18:00+'
# Before cleanup - days_part: 'Apr-Oct: Tu,We' | times_part: '15:00-18:00'
# Before cleanup - days_part: 'Apr-Oct: Sat,Su' | times_part: '14:00-18:00'
# Before cleanup - days_part: 'We-Su' | times_part: '18:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Mon-Fri 09:00-13:00, Tu,Th' | times_part: '14:00-16:00'
# Before cleanup - days_part: 'Mon-Fri 09:00-13:00, Tu,Th' | times_part: '14:00-16:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-13:00,14:30-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-13:00,14:30-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:11-07:48'
# Before cleanup - days_part: 'SH off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:11-07:48'
# Before cleanup - days_part: 'SH off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:11-07:48'
# Before cleanup - days_part: 'SH off' | times_part: ''
# Before cleanup - days_part: 'Su' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '10:00-01:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '10:00-01:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '10:00-01:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-11:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-12:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-11:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-12:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-12:30'
# Before cleanup - days_part: 'Mon,Tu,Th,Fri' | times_part: '15:00-18:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:45-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-12:30'
# Before cleanup - days_part: 'Su' | times_part: '07:30-12:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:45-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-12:30'
# Before cleanup - days_part: 'Su' | times_part: '07:30-12:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:45-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-12:30'
# Before cleanup - days_part: 'Su' | times_part: '07:30-12:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:30-13:00,14:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:30-13:00,14:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:30-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:30-23:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:30-13:00,14:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:30-13:00,14:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:30-13:00,14:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:30-13:00,14:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '09:00-14:30'
# Before cleanup - days_part: 'Sat' | times_part: '11:00-16:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-17:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Fri' | times_part: '09:00-14:30'
# Before cleanup - days_part: 'Sat' | times_part: '11:00-16:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-17:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon,We' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Mon,We' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: 'Mon,We,Fri' | times_part: '09:00-14:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon,We,Fri' | times_part: '09:00-14:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon' | times_part: '08:00-12:00,16:00-18:00'
# Before cleanup - days_part: 'Tu' | times_part: '08:00-12:00,16:00-18:00'
# Before cleanup - days_part: 'We' | times_part: '08:00-12:00'
# Before cleanup - days_part: 'Th 08:00-12:00, Fri' | times_part: '07:30-12:00'
# Before cleanup - days_part: 'Mon' | times_part: '08:00-12:00,16:00-18:00'
# Before cleanup - days_part: 'Tu' | times_part: '08:00-12:00,16:00-18:00'
# Before cleanup - days_part: 'We' | times_part: '08:00-12:00'
# Before cleanup - days_part: 'Th 08:00-12:00, Fri' | times_part: '07:30-12:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri 09:00-13:00,15:00-18:00, Sat' | times_part: '10:00-13:00'
# Before cleanup - days_part: 'Mon-Fri 09:00-13:00,15:00-18:00, Sat' | times_part: '10:00-13:00'
# Before cleanup - days_part: '"Schild derzeit: 12-20 Uhr. Variiert aber je nach' | times_part: 'Wetterlage."'
# Before cleanup - days_part: '"Schild derzeit: 12-20 Uhr. Variiert aber je nach' | times_part: 'Wetterlage."'
# Before cleanup - days_part: '"Schild derzeit: 12-20 Uhr. Variiert aber je nach' | times_part: 'Wetterlage."'
# Before cleanup - days_part: 'Mon,We' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Mon,We' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '06:00-00:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-00:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: '06' | times_part: '00-23:00'
# Before cleanup - days_part: 'sunset-sunrise' | times_part: ''
# Before cleanup - days_part: 'sunset-sunrise' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:30-15:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-15:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:30-15:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-15:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:30-15:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-15:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:30-12:30'
# Before cleanup - days_part: 'Mon-Tu' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Th-Fri' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:30-12:30'
# Before cleanup - days_part: 'Mon-Tu' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Th-Fri' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:30-12:30'
# Before cleanup - days_part: 'Mon-Tu' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Th-Fri' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon 11:00-18:00, Tu 15:00-18:00, We-Fri 11:00-18:00, Sat' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:30-12:30'
# Before cleanup - days_part: 'Mon-Tu' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Th-Fri' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '11:15-22:30'
# Before cleanup - days_part: 'We,Sat' | times_part: '15:30-22:30'
# Before cleanup - days_part: 'Fri' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:30'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '11:15-22:30'
# Before cleanup - days_part: 'We,Sat' | times_part: '15:30-22:30'
# Before cleanup - days_part: 'Fri' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:30'
# Before cleanup - days_part: '07' | times_part: '00-19:00'
# Before cleanup - days_part: 'sunset+ closed' | times_part: ''
# Before cleanup - days_part: '07' | times_part: '00-19:00'
# Before cleanup - days_part: 'sunset+ closed' | times_part: ''
# Before cleanup - days_part: '07' | times_part: '00-19:00'
# Before cleanup - days_part: 'sunset+ closed' | times_part: ''
# Before cleanup - days_part: 'Mon,We,Fri' | times_part: '09:00-14:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00+'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00+'
# Before cleanup - days_part: '07' | times_part: '00-19:00'
# Before cleanup - days_part: 'sunset+ closed' | times_part: ''
# Before cleanup - days_part: 'Mon' | times_part: '14:00-18:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '09:00-12:00,14:00-18:00'
# Before cleanup - days_part: 'Fri' | times_part: '09:30-12:00,14:00-18:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00-12:00,14:00-16:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'We,Fri-Sat' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '10:00-13:00,14:30-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-17:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-20:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:30-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon,We,Fri' | times_part: '09:00-14:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon,We,Fri' | times_part: '09:00-14:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon-Fri 08:30-13:00,' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Fri 08:30-13:00,' | times_part: '15:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Su' | times_part: '07:30-11:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-12:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-11:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-12:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-11:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-12:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-13:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-16:30'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-13:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-16:30'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon,We' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Mon,We' | times_part: '09:00-13:00,14:00-16:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-14:30,18:00-22:30'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-14:30,18:00-22:30'
# Before cleanup - days_part: 'Mon-Sat 08:00-13:00, Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Mon-Sat 08:00-13:00, Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Mon-Sat 08:00-13:00, Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '8:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Su' | times_part: '15:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '15:00-17:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:30-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-13:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-11:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-12:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-13:00,15:00-18:00'
# Before cleanup - days_part: 'We,Sat' | times_part: '08:30-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-13:00,15:00-18:00'
# Before cleanup - days_part: 'We,Sat' | times_part: '08:30-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-13:00,15:00-18:00'
# Before cleanup - days_part: 'We,Sat' | times_part: '08:30-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-13:00,15:00-18:00'
# Before cleanup - days_part: 'We,Sat' | times_part: '08:30-13:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-13:00,15:00-18:00'
# Before cleanup - days_part: 'We,Sat' | times_part: '08:30-13:00'
# Before cleanup - days_part: 'Mon,We-Th' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '15:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-21:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '14:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-16:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Mon-Su' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '10:00-13:00,14:30-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-17:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:30-13:00'
# Before cleanup - days_part: 'Su' | times_part: '07:00-13:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '9:30-17:00'
# Before cleanup - days_part: '24/7' | times_part: ''

# %%
# Add Still & Wickelplätze
wickelplaetze = gpd.read_file('still-und-wickelplaetze-muenster-2023.geojson')

# %%
for idx, row in wickelplaetze.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        popup_text = f"<strong>{row['Name']}</strong><br>" \
                    f"Adresse: {row['Straße']}<br>" \
                    f"Stockwerk: {row['Stockwerk'] if pd.notna(row['Stockwerk']) else 'nicht angegeben'}<br>" \
                    f"Typ: {row['Typ']}"
        marker = folium.Marker(
            location=[lat, lon],
            popup=popup_text,
            icon=folium.Icon(color='lightblue',icon='baby',prefix='fa')
        ).add_to(wickelplaetze_cluster)

# %%
# Add Give Boxen
give_boxen = gpd.read_file('give_boxen.geojson')
for idx, row in give_boxen.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        popup_text = f"<strong>{row['Bezeichnung']}</strong><br>" \
                    f"Adresse: {row['Adresse (ungefähr)']}<br>" \
                    f"Betreiber: {row['Betreiber']}<br>" \
                    f"Mehr Info: <a href='{row['Infos im Internet']}' target='_blank'>{row['Infos im Internet']}</a>"
        
        # Add opening hours if available
        if 'Öffnungszeiten' in row and pd.notna(row['Öffnungszeiten']):
            formatted_hours = format_opening_hours(row['Öffnungszeiten'])
            popup_text += f"Öffnungszeiten: {formatted_hours}<br>"
        
        folium.Marker(
            location=[lat, lon],
            popup=popup_text,
            icon=folium.Icon(color='beige', icon='box-open',prefix='fa')
        ).add_to(give_boxen_cluster)
# Out:
# Before cleanup - days_part: 'immer' | times_part: ''
# Before cleanup - days_part: '8-18 Uhr' | times_part: ''
# Before cleanup - days_part: 'Mon to Fri 14-20 Uhr' | times_part: ''
# Before cleanup - days_part: 'immer' | times_part: ''
# Before cleanup - days_part: 'immer' | times_part: ''
# Before cleanup - days_part: 'immer' | times_part: ''
# Before cleanup - days_part: 'Monntag to Frieitag 10-17 Uhr, Satmstag 10-16 Uhr' | times_part: ''
# Before cleanup - days_part: 'Wedttwoch 12-19 Uhr, alle zwei Wochen  Frieitag: 12 - 19' | times_part: 'Uhr'
# Before cleanup - days_part: 'Monntag to Frieitag 8-19 Uhr, Satmstag 9.30-19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Tueenstag 12-19 Uhr, Thunnerstag 12-19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Mon to Fri 8.30 to 19 Uhr, Sat 9.30 to 19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Tueenstag 12-19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Mon 12 to 19 Uhr, Wed 8.30 to 13 Uhr, Fri 12 to 19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Tueenstag 12-19 Uhr, Thunnerstag 8.30-13 Uhr' | times_part: ''
# Before cleanup - days_part: 'Wedttwoch 8.30-13 Uhr, Frieitag 12-19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Mon 12 to 19 Uhr, Thu 12 to 19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Monntag 12-19 Uhr' | times_part: ''
# Before cleanup - days_part: 'Tue 12 to 19 Uhr, Thu 8.30 to 13 Uhr' | times_part: ''
# Before cleanup - days_part: '?' | times_part: ''
# Before cleanup - days_part: '?' | times_part: ''
# Before cleanup - days_part: '?' | times_part: ''
# Before cleanup - days_part: '?' | times_part: ''
# Before cleanup - days_part: '?' | times_part: ''
# Before cleanup - days_part: 'immer' | times_part: ''
# Before cleanup - days_part: '13' | times_part: '30-23:00'
# Before cleanup - days_part: 'Mon to Sun 10-17 Uhr' | times_part: ''

# %%
# Add Kinos 
kinos=gpd.read_file('kinos.geojson')
columns_to_show = ['NAME', 'STR_NAME', 'HOMEPAGE','opening_hours']

# %%
for idx, row in kinos.iterrows():
    if row.geometry:
        # Extract coordinates
        lon, lat = row.geometry.x, row.geometry.y
        
        # Create popup content
        popup_lines = []
        for col in columns_to_show:
            if col in row and pd.notnull(row[col]):
                # For STR_NAME, append HSNR if it exists
                if col == 'STR_NAME':
                    address = str(row[col])
                    if 'HSNR' in row and pd.notnull(row['HSNR']):
                        address += f" {int(row['HSNR'])}" #convert to int to remove decimal
                    popup_lines.append(f"<b>Address:</b> {address}")
                # Handle HOMEPAGE 
                elif col == 'HOMEPAGE' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>Homepage:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                # For NAME, just add it normally
                elif col == 'NAME':
                    popup_lines.append(f"<b>Name:</b> {row[col]}")
                # Add Opening Hours
                elif col =='opening_hours':
                    formatted_hours= format_opening_hours(row[col])
                    popup_lines.append(f"<b>Opening Hours:</b><br>{formatted_hours}") 
        
        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='green', icon='ticket', prefix='fa')
            ).add_to(kinos_cluster)
# Out:
# Before cleanup - days_part: 'Mon-Wed' | times_part: '15:00-21:15'
# Before cleanup - days_part: 'Thu-Fri' | times_part: '15:00-23:15'
# Before cleanup - days_part: 'Sat' | times_part: '12:15-23:15'
# Before cleanup - days_part: 'Sun' | times_part: '10:15-21:15'
# Before cleanup - days_part: 'Mon-Wed' | times_part: '14:00-22:00'
# Before cleanup - days_part: 'Thu-Fri' | times_part: '14:00-00:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-00:00'
# Before cleanup - days_part: 'Sun' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Mon-Tue' | times_part: '17:30+'
# Before cleanup - days_part: 'Wed-Sat' | times_part: '15:00+'
# Before cleanup - days_part: 'Sun' | times_part: '10:45+'

# %%
# Add Kinderspielplätze 
kinder=gpd.read_file('spielplaetze.geojson')
columns_to_show=['Name']
for idx, row in kinder.iterrows():
    if row.geometry:
        lon, lat= row.geometry.x, row.geometry.y
        # Format the values in the name column, so that the street names are not in caps
        name =str(row['Name'])
        if name.startswith('SP'):
            formatted_name ='SP'+' '+name[2:].strip().title()
        else:
            formatted_name=name.strip().title()

        popup_text = "<br>".join(
            f"<b>{col}:</b> {formatted_name if col == 'Name' else row[col]}" 
                for col in columns_to_show 
                if col in kinder.columns and pd.notnull(row[col])
        )
        folium.Marker(
            location=[lat,lon],
            popup=folium.Popup(popup_text, max_width=300),
            icon=folium.Icon(color='cadetblue', icon='child', prefix='fa')
        ).add_to(kinder_cluster)

# %%
# Add Friedhöfe
friedhof=gpd.read_file('friedhoefe.geojson')
columns_to_show = ['NAME','HOMEPAGE']

# %%
for idx, row in friedhof.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        
        popup_lines = []
        for col in columns_to_show:
            if col in row and pd.notnull(row[col]):
                #Format column name for display ( first letter capitalized)
                display_name=col[0].upper()+col[1:].lower() if col else col
                # Make URLs clickable
                if col.lower() == 'homepage' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>{display_name}:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                else:
                    popup_lines.append(f"<b>{display_name}:</b> {row[col]}")
        
        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='darkblue', icon='cross', prefix='fa')
            ).add_to(friedhof_cluster)

# %%
# Add Refill Stationen 
refill=gpd.read_file('refill_stations.geojson')
columns_to_show = ['Name','Straße','PLZ','Beschreibung','Homepage']

# %%
for idx, row in refill.iterrows():
    if row.geometry:
        lon, lat = row.geometry.x, row.geometry.y
        
        popup_lines = []
        for col in columns_to_show:
            if col in row and pd.notnull(row[col]):
                # Make URLs clickable
                if col == 'Homepage' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>{col}:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                else:
                    popup_lines.append(f"<b>{col}:</b> {row[col]}")
        
        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='blue', icon='tint', prefix='fa')
            ).add_to(refill_cluster)

# %%
#Add Gastronomie 
gastro=gpd.read_file('muenster_gastronomie.geojson')
columns_to_show=['name','addr:street','addr:housenumber','contact:phone','opening_hours','website']
for idx, row in gastro.iterrows():
    if row.geometry and pd.notnull(row.geometry):
        lon, lat = row.geometry.x, row.geometry.y
        
        popup_lines = []
        # Manually add name first if it exists
        if 'name' in row and pd.notnull(row['name']):
            popup_lines.append(f"<b>Name:</b> {row['name']}")

        # Create address from street and housenumber
        address = ""
        if 'addr:street' in row and pd.notnull(row['addr:street']):
            address += row['addr:street']
        if 'addr:housenumber' in row and pd.notnull(row['addr:housenumber']):
            address += f" {row['addr:housenumber']}"
        if address:
            popup_lines.append(f"<b>Address:</b> {address.strip()}")

        # Add other details, excluding ones already handled
        other_cols = ['contact:phone', 'opening_hours', 'website']
        for col in other_cols:
            if col in row and pd.notnull(row[col]):
                display_name = col.replace('_', ' ').replace(':', ' ').title()
                # Make website URL clickable
                if col == 'website' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>{display_name}:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                elif col =='opening_hours':
                    formatted_hours= format_opening_hours(row[col])
                    popup_lines.append(f"<b>{display_name}:</b><br>{formatted_hours}")
                else:
                    popup_lines.append(f"<b>{display_name}:</b> {row[col]}")

        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='lightred', icon='utensils', prefix='fa')
            ).add_to(gastro_cluster)
# Out:
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Su' | times_part: '10:00-21:00'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'We,Fri-Sat' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '18:00-20:30'
# Before cleanup - days_part: 'Su' | times_part: '10:00-20:30'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Th 09:00-24:00, Fri,Sat 09:00-01:00, Su' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:45-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-12:30'
# Before cleanup - days_part: 'Su' | times_part: '07:30-12:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '19:00-02:00'
# Before cleanup - days_part: 'We,Fri,Sat 19:00-03:00, Mon,Tu 19:00-24:00, Th 19:00-01:00, Su' | times_part: '19:00-23:00'
# Before cleanup - days_part: 'Mon-Sat 17:00-24:00, Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '17:00-02:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '18:00-02:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-02:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '9:00-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Fri-Su' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '20:00-03:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Su,Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Su' | times_part: '14:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-22:30'
# Before cleanup - days_part: 'Mon-Tu,Th-Fri' | times_part: '11:00-15:00,17:00-22:00'
# Before cleanup - days_part: 'We off' | times_part: ''
# Before cleanup - days_part: 'Sat-Su' | times_part: '13:00-22:00'
# Before cleanup - days_part: 'Mon-Sat 10:00-24:00, Su' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '18:00+'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-14:15'
# Before cleanup - days_part: 'Mon-Sat 12:00-14:30,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Mon,We,Fri' | times_part: '12:00-16:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '17:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '14:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '14:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'We-Su' | times_part: '18:00+'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:00-15:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-15:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '07:00-10:00,16:00-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '07:00-10:00,15:00-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '14:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '19:00+'
# Before cleanup - days_part: 'Su' | times_part: '15:00+'
# Before cleanup - days_part: 'Mon-Th' | times_part: '12:00-14:30,17:30-22:30'
# Before cleanup - days_part: 'Fri' | times_part: '12:00-14:30,17:30-23:30'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Mon,Tu,We,Fri,Sat' | times_part: '12:00-14:00,18:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '11:30-14:00,18:00-22:00'
# Before cleanup - days_part: 'Th off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '17:30-22:30'
# Before cleanup - days_part: 'Tu-Th' | times_part: '19:00-01:00'
# Before cleanup - days_part: 'Fri, Sat' | times_part: '19:00-02:00'
# Before cleanup - days_part: 'Mon-Sat 11:00-22:00, Su' | times_part: '15:00-22:00'
# Before cleanup - days_part: 'Mon,We-Th' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '15:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '18:00-23:00'
# Before cleanup - days_part: '12' | times_part: '00-14:30,17:30-23:30'
# Before cleanup - days_part: 'We' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Fri, Sat' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Su 12:00-14:00,' | times_part: '17:00-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '09:00-24:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-00:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '09:00-00:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Su' | times_part: '16:00-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-14:30,18:00-22:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'We-Su' | times_part: '12:00-14:30,18:00-22:00'
# Before cleanup - days_part: 'Mon' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-19:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-01:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:00-01:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-21:00'
# Before cleanup - days_part: 'Mon-Fri 11:00-01:00, Sat 10:00-01:00, Su "nur an verkaufsunffenen' | times_part: 'Sonntagen"'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:30-19:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-19:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-18:30'
# Before cleanup - days_part: 'Su-Th 10:00-01:00+, Fri,Sat' | times_part: '10:00-03:00+'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '12:00-14:00,18:00-22:00'
# Before cleanup - days_part: 'Su,Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-20:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-19:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-22:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Fri 12:00-15:00,18:00-01:00, Sat' | times_part: '18:00-03:00'
# Before cleanup - days_part: 'Su-Th 09:00-01:00, Fri-Sat' | times_part: '09:00-03:00'
# Before cleanup - days_part: 'Fri,Sat 12:00-14:30, Mon-Sat' | times_part: '18:00-22:30'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Sat 12:00-14:30,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: '12' | times_part: '00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-18:00+'
# Before cleanup - days_part: 'Mon-Th 17:00-23:00, Fri 17:00-00:00, Sat' | times_part: '14:00-00:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Dec 24-26,31,Jan 01 off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Tu-Su,' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Sat 09:00-01:00, Su' | times_part: '11:00-01:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-15:00,17:30-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-18:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-15:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '18:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: '18' | times_part: '00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00+'
# Before cleanup - days_part: 'Su' | times_part: '09:30+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Mon,Tu,Th' | times_part: '11:00-03:00'
# Before cleanup - days_part: 'We,Fri,Sat' | times_part: '11:00-05:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-03:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:30-22:00,12:00-14:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '19:00-23:00+'
# Before cleanup - days_part: 'Mon-Th 11:30-22:00, Fri-Su' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:20-14:40'
# Before cleanup - days_part: 'Sat-Su off' | times_part: ''
# Before cleanup - days_part: '17' | times_part: '20-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '09:00-24:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Jul-Sep Th-Sat' | times_part: '21:00-03:00+'
# Before cleanup - days_part: 'Oct-Jun Th-Sat' | times_part: '19:00-05:00'
# Before cleanup - days_part: 'Mon, We-Su' | times_part: '12:00-15:00'
# Before cleanup - days_part: 'Mon, We-Sat' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:30-22:00'
# Before cleanup - days_part: 'Su-We 09:00-24:00, Th 09:00-01:00, Fri-Sat' | times_part: '09:00-02:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Mon,We-Fri' | times_part: '17:00-22:30'
# Before cleanup - days_part: 'Su-Mon 11:00-02:00, Tu-Sat 11:00-05:00, Su' | times_part: '12:00-02:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '16:00+'
# Before cleanup - days_part: 'Th-Tu' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'We off, Su' | times_part: '12:00-14:30'
# Before cleanup - days_part: 'May-Oct: Mon-Sat' | times_part: '11:30+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '17:00+'
# Before cleanup - days_part: 'Su' | times_part: '11:30+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '17:30-24:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-14:30,17:30-24:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-22:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-20:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:30-23:00'
# Before cleanup - days_part: 'Fri-Mon' | times_part: '12:00-14:00,18:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Su' | times_part: '17:00-21:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-20:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '18:30-24:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-15:00,18:30-24:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Tu-Fri' | times_part: '12:00-16:30'
# Before cleanup - days_part: 'Sat' | times_part: '11:30-17:00'
# Before cleanup - days_part: 'Mon-Fri 08:00-10:45,' | times_part: '12:00-14:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '11:00-00:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '17:00-24:00+'
# Before cleanup - days_part: 'Fri-Su' | times_part: '12:00-24:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '06:30+'
# Before cleanup - days_part: 'Su' | times_part: '07:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-14:30'
# Before cleanup - days_part: 'Sat' | times_part: '06:30-12:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-11:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '13:00-21:00'
# Before cleanup - days_part: 'Mon,Th,Fri' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'Tu' | times_part: '12:00-02:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Sat off' | times_part: ''
# Before cleanup - days_part: 'Tu-Sat' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '14:00-21:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00+'
# Before cleanup - days_part: 'Su' | times_part: '10:00+'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:45'
# Before cleanup - days_part: '08' | times_part: '30-14:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '13:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-16:30'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-20:00'
# Before cleanup - days_part: 'Mon-Fri 11:00-14:30,' | times_part: '17:00-21:30'
# Before cleanup - days_part: 'Sat' | times_part: '16:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '11:00-15:00,17:00-21:30'
# Before cleanup - days_part: '11' | times_part: '00-14:30,17:00-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '08:00-15:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Su' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00-21:00'
# Before cleanup - days_part: '12' | times_part: '00-21:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '17:00-01:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Fri' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Mon-Sat 12:00-14:30,18:00-01:00, Su' | times_part: '12:00-14:30,17:00-01:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '16:00-23:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-19:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-14:00,17:00-23:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '18:00+'
# Before cleanup - days_part: 'Tu-Fri 11:00-15:00, Sat,Su' | times_part: '13:00-22:00'
# Before cleanup - days_part: 'Mon off, Tu-Fri' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '17:00-20:30'
# Before cleanup - days_part: 'Sat' | times_part: '19:00-24:00'
# Before cleanup - days_part: 'Mon-Th 14:30-17:30, Fri' | times_part: '09:30-12:30'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Sat' | times_part: '13:00-21:30'
# Before cleanup - days_part: 'Su' | times_part: '16:00-21:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:45'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '18:00-23:55'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-15:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon, Tu' | times_part: '11:00-02:00'
# Before cleanup - days_part: 'We, Th' | times_part: '11:00-03:00'
# Before cleanup - days_part: 'Fri' | times_part: '11:00-05:00'
# Before cleanup - days_part: 'Sat' | times_part: '13:00-05:00'
# Before cleanup - days_part: 'Su' | times_part: '13:00-02:00'
# Before cleanup - days_part: 'Mon-Sat 17:00-23:00, Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'We-Su' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Mon-Tu 17:00-01:00, Fri-Su' | times_part: '12:00-01:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Fri' | times_part: '12:00-15:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:30-22:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '09:30-21:30'
# Before cleanup - days_part: 'Su-Th 21:00-05:00, Fri-Sat' | times_part: '21:00-06:00'
# Before cleanup - days_part: 'Mon-Fri 11:30-14:00,' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Sat, Su,' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon' | times_part: '14:00-17:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '10:00-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Th-Tu' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Th-Sat' | times_part: '20:00-03:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '18:00-05:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-22:30'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-16:00'
# Before cleanup - days_part: 'Mon,Tu,Th,Fri 17:00-23:00, Sat,Su' | times_part: '11:00-14:00,17:00-22:00'
# Before cleanup - days_part: 'Mon,We-Fri' | times_part: '11:00-15:00,17:00-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '13:00-22:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon,We,Th 11:00-24:00, Tu 11:00-02:00, Fri,Sat 11:00-05:00, Su' | times_part: '12:30-24:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '12:00-15:30,17:00-21:30'
# Before cleanup - days_part: 'Sat' | times_part: '17:00-21:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Tu-Th 20:00-01:00, Fri,Sat' | times_part: '20:00-03:00'
# Before cleanup - days_part: 'Mon,Tu' | times_part: '11:00-03:30'
# Before cleanup - days_part: 'We' | times_part: '11:00-05:00'
# Before cleanup - days_part: 'Th' | times_part: '11:00-03:30'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-05:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-24:00'
# Before cleanup - days_part: '11' | times_part: '00-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '07:30-18:00'
# Before cleanup - days_part: 'Fri' | times_part: '07:30-13:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-13:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: '08' | times_part: '00-12:00'
# Before cleanup - days_part: 'Mon-Fri 12:00-15:00,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su 12:00-14:00,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '15:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '15:00-19:00'
# Before cleanup - days_part: 'We-Su' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '10:30-16:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:15-14:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '17:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '11:30-14:30,17:00-24:00'
# Before cleanup - days_part: 'Mon-Th 15:00-24:00, Fri 15:00-01:00, Sat 12:00-01:00, Su' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Tu 19:00-01:00, We 19:00-03:00, Th 19:00-01:00, Fri-Sat' | times_part: '19:00-03:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:00-22:00+'
# Before cleanup - days_part: 'We-Su' | times_part: '17:30-18:00+'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu-Fri 12:00-15:00,' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Sat, Su,' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu-Su,' | times_part: '17:00+'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Su-Th 17:00-24:00, Fri 17:00-02:00, Sat' | times_part: '17:00-01:00'
# Before cleanup - days_part: 'Th,Fri,Su' | times_part: '17:00-24:00+'
# Before cleanup - days_part: 'We-Su' | times_part: '17:30-23:00'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Mon,We-Sat' | times_part: '09:00-17:30'
# Before cleanup - days_part: 'Su' | times_part: '09:30-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-14:30,17:30-24:00'
# Before cleanup - days_part: 'Tu,Sat' | times_part: '17:30-24:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'We-Mon' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-15:30,17:30-21:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-16:00,17:00-21:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-16:00,17:00-21:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'We-Mon' | times_part: '12:00-14:00,18:00-23:00'
# Before cleanup - days_part: 'Fri' | times_part: '17:00-00:00'
# Before cleanup - days_part: 'Sat' | times_part: '15:00-00:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '18:00-00:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '18:00-02:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '18:00-01:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '18:00+'
# Before cleanup - days_part: 'Su-Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-13:30'
# Before cleanup - days_part: 'Mon-Fri 11:00-01:00, Sat 17:00-01:00, Su' | times_part: '15:00-24:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-19:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-16:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-19:00'
# Before cleanup - days_part: '10' | times_part: '00-24:00'
# Before cleanup - days_part: 'We-Su' | times_part: '17:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:30-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:00-20:00'
# Before cleanup - days_part: 'Mon 18:00-24:00, Tu-Th 18:00-02:00, Fri 18:00-03:00, Sat 15:00-03:00, Su' | times_part: '15:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '18:00-01:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-14:30,17:00-22:00'
# Before cleanup - days_part: 'Sat off' | times_part: ''
# Before cleanup - days_part: 'Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Tu-Su 18:00-23:00, Mon' | times_part: 'off'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:00-23:00+'
# Before cleanup - days_part: 'We-Sat' | times_part: '19:00-12:00+'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-16:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Th 11:00-22:00, Fri,Sat 11:00-23:00, Su' | times_part: '13:00-23:00'
# Before cleanup - days_part: 'We-Su' | times_part: '17:30+'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Fri-Su' | times_part: '10:00-20:00'
# Before cleanup - days_part: 'Tu-Th 18:00-23:00, Fri 18:00-02:00, Sat' | times_part: '14:00-02:00'
# Before cleanup - days_part: 'Tu-Th 11:30-23:00, Fri,Sat 12:00-24:00, Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '17:00-00:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '12:00-00:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Tu-We' | times_part: '17:00-01:00'
# Before cleanup - days_part: 'Th-Sat' | times_part: '17:00-03:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Su' | times_part: '12:30-21:00'
# Before cleanup - days_part: 'Mon,We-Fri' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '12:00-14:30,17:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '17:30-22:00'
# Before cleanup - days_part: 'We-Fri,Su,Mon' | times_part: '12:00-14:30,17:30-22:00'
# Before cleanup - days_part: 'Tu,Th,Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '11:30-15:00,17:30-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-15:00,17:30-22:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Tu-Sat' | times_part: '11:00-15:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-19:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-19:00'
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Su-Th 10:00-00:00, Fri-Sat' | times_part: '10:00-03:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:30-21:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:30-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-20:00'
# Before cleanup - days_part: 'Su' | times_part: '11:30-14:30,17:30-24:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-01:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:30-18:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '08:00-15:00'
# Before cleanup - days_part: 'Fri' | times_part: '08:00-14:00'
# Before cleanup - days_part: 'Mon-Tu,Th-Fri' | times_part: '12:00-14:30,17:00-22:00'
# Before cleanup - days_part: 'We,Sat-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-19:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-14:30,17:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-23:30'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-01:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-14:30,17:00-23:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '17:45-00:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-14:00,17:00-20:30'
# Before cleanup - days_part: 'Sat,Su' | times_part: '17:00-20:30'
# Before cleanup - days_part: '17' | times_part: '00-20:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:30-22:30'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Sat,Su' | times_part: '11:30-20:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:30-22:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-14:30,17:30-22:30'
# Before cleanup - days_part: '12' | times_part: '00-14:30,17:30-22:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Su' | times_part: '07:00-13:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '17:00-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Su' | times_part: '13:00-18:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-17:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-14:30,18:00-23:30'
# Before cleanup - days_part: 'Sat' | times_part: '17:00-23:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-23:00'
# Before cleanup - days_part: '11:30-14:00,' | times_part: '17:00-22:30'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Fri' | times_part: '12:00-14:30,18:00+'
# Before cleanup - days_part: 'Sat' | times_part: '18:00+'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'Su' | times_part: '12:00-14:30,18:00+'
# Before cleanup - days_part: 'Mon-Fri 10:00-23:00, Fri 10:00-24:00, Sat 09:00-24:00, Su' | times_part: '09:00-23:00'
# Before cleanup - days_part: 'Mon' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Fri' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-20:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '15:00-22:00'
# Before cleanup - days_part: 'Mon-Th 12:00-15:00,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Fri, Sat' | times_part: '17:30-23:30'
# Before cleanup - days_part: 'Mon' | times_part: '11:00-14:00,17:00-21:00'
# Before cleanup - days_part: 'Tu' | times_part: '17:00-21:00'
# Before cleanup - days_part: 'We-Fri' | times_part: '11:00-14:00,17:00-21:00'
# Before cleanup - days_part: 'Sat' | times_part: '17:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-21:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '12:00+'
# Before cleanup - days_part: 'Mon,We-Fri 12:00-14:00, Mon-Fri 17:00-22:00, Sat 14:00-22:00, Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-23:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Tu-Fri,Su' | times_part: '17:00-18:00+'
# Before cleanup - days_part: 'Sat' | times_part: '15:00-18:00+'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-14:30,17:30-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '15:00-24:00'
# Before cleanup - days_part: 'Mon, Tu, Th' | times_part: '19:00-01:00'
# Before cleanup - days_part: 'We' | times_part: '19:00-02:00'
# Before cleanup - days_part: 'Fri, Sat' | times_part: '19:00-05:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-00:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-15:00,17:30-23:30'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '15:00-22:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'We-Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '11:30-15:00,17:30-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '15:00-22:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '13:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '14:00-21:00'
# Before cleanup - days_part: 'Tu-Sat 18:00+, Su' | times_part: '17:00+'
# Before cleanup - days_part: 'Mon' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '17:00+'
# Before cleanup - days_part: 'Sat' | times_part: '15:00+'
# Before cleanup - days_part: 'Su' | times_part: '15:00+'
# Before cleanup - days_part: 'Tu-Su' | times_part: '14:30-22:30'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Su 11:00-14:00,' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '17:00-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'closed' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-20:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '11:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:30-20:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Th 12:00-14:30,' | times_part: '18:00-00:00'
# Before cleanup - days_part: 'Fri 12:00-14:30,' | times_part: '18:00-02:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-02:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-23:00'
# Before cleanup - days_part: '17' | times_part: '00+'
# Before cleanup - days_part: 'Mon-Th 07:00-24:00, Fri,Sat 07:00-01:00, Su' | times_part: '09:00-24:00'
# Before cleanup - days_part: 'We-Su' | times_part: '09:30-17:30'
# Before cleanup - days_part: 'Tu' | times_part: '08:30-17:30'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-15:00,17:30-21:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-20:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-20:00'
# Before cleanup - days_part: '"Schild derzeit: 12-20 Uhr. Variiert aber je nach' | times_part: 'Wetterlage."'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:00-18:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Mon-Fri 10:00-05:00, Sat 11:00-05:00, Su' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'We-Mon' | times_part: '17:30-23:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-21:30'
# Before cleanup - days_part: 'We-Th' | times_part: '19:00-24:00'
# Before cleanup - days_part: 'Fri' | times_part: '19:00-02:00'
# Before cleanup - days_part: 'Sat' | times_part: '14:00-02:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:30-20:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-19:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-21:00+'
# Before cleanup - days_part: 'Su' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon,Tu,Th,Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'We,Sat' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Tu-Th' | times_part: '11:30-14:30,15:00-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '11:30-14:30,15:00-22:15'
# Before cleanup - days_part: 'Sat' | times_part: '14:00-22:15'
# Before cleanup - days_part: 'Su' | times_part: '14:00-22:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '12:00-14:30,17:30-21:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Mon,We,Th 19:00-02:00, Fri,Sat' | times_part: '19:00-03:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:30-24:00'
# Before cleanup - days_part: 'Mon-Sat 11:00-01:00, Su' | times_part: '15:00-01:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-18:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Sat[3]' | times_part: '14:00-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Fri 12:00-14:30,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Sat' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su 11:00-14:00,' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '10:00-14:00'
# Before cleanup - days_part: '17' | times_part: '00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-14:30'
# Before cleanup - days_part: '17' | times_part: '00-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Mon,Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-14:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-16:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:30-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '12:00-14:30,18:00-22:30'
# Before cleanup - days_part: 'Sat' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Fri' | times_part: '10:00-16:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-15:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-23:30'
# Before cleanup - days_part: 'Tu-Su' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'We-Su' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'Tu-Fri' | times_part: '09:00-15:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:30-16:30'
# Before cleanup - days_part: 'Su' | times_part: '07:30-16:00'
# Before cleanup - days_part: 'Tu-Th,Su' | times_part: '10:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '10:00-12:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '17:30-22:30'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-18:00'
# Before cleanup - days_part: 'Mon-Fri 8:00+,' | times_part: '11:45-13:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '11:30-01:00'
# Before cleanup - days_part: 'Su' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:30-22:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '12:00-14:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-14:00,18:00-21:30'
# Before cleanup - days_part: '17' | times_part: '30-01:30'
# Before cleanup - days_part: 'Mon-Tu,Th' | times_part: '11:15-22:30'
# Before cleanup - days_part: 'We,Sat' | times_part: '15:30-22:30'
# Before cleanup - days_part: 'Fri' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '13:00-22:30'
# Before cleanup - days_part: 'Mon-Th' | times_part: '16:00-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '14:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Mon-Fri 08:00-22:00, Sat-Su 10:00-20:00 "Außerhalb der' | times_part: 'Semesterferien"'
# Before cleanup - days_part: 'Mon-Fri 08:00-18:00, Sat-Su 10:00-16:00 "Innerhalb der' | times_part: 'Semesterferien"'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: '11' | times_part: '00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00-20:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '11:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-17:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-20:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-14:30,17:30-19:30'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'We' | times_part: '18:00-23:00'
# Before cleanup - days_part: 'Fri' | times_part: '18:00-00:00'
# Before cleanup - days_part: 'Sat' | times_part: '12:00-00:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Th 11:00-23:00, Fri-Su' | times_part: '11:00-01:00'
# Before cleanup - days_part: 'Su-Th 11:30-22:30, Fri 11:30-03:00, Sat' | times_part: '14:00-05:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-15:00,17:30-23:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Fri,Sat' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Tu-Th,Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Th-Fri' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '15:00-23:00'
# Before cleanup - days_part: 'We-Su' | times_part: '17:00-24:00'
# Before cleanup - days_part: 'Th-Fri' | times_part: '14:00-20:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '11:00-20:00'
# ...
# Before cleanup - days_part: 'Sat' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Mon-Sat 12:00-14:30,' | times_part: '17:30-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '11:00-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-19:30'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-14:00,17:00-24:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '17:00-22:00'
# Before cleanup - days_part: '11' | times_part: '30-22:00'
# Before cleanup - days_part: 'Mon-Th, Su' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Fri, Sat' | times_part: '17:00-00:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Sat' | times_part: '12:00-14:30,17:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '17:00-22:30'
# Before cleanup - days_part: 'Mon-Sat 10:00-22:00, Su' | times_part: '14:00-20:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-14:30,16:30-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'We-Su' | times_part: '10:00-21:00'
# Before cleanup - days_part: 'We-Mon' | times_part: '09:00-24:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Tu-Su' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon closed' | times_part: ''
# Before cleanup - days_part: 'Mon,Su' | times_part: '15:00-22:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '15:00-24:00'
# Before cleanup - days_part: 'We,Fri-Sat' | times_part: '15:00+'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Tu-Fri,Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '14:00-22:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '13:00-00:00'
# Before cleanup - days_part: '10' | times_part: '00-17:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-22:00'
# Before cleanup - days_part: '10' | times_part: '00-22:00'
# Before cleanup - days_part: '11' | times_part: '30-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:00-22:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '05:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '06:00-23:00'
# Before cleanup - days_part: 'Fri, Sat' | times_part: '17:00-21:30'
# Before cleanup - days_part: 'Su' | times_part: '16:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:45-10:30,11:45-14:00'
# Before cleanup - days_part: 'Mon' | times_part: '09:30-18:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '09:30-19:00'
# Before cleanup - days_part: 'Su' | times_part: '09:30-18:00'
# Before cleanup - days_part: 'Tu-Fri,Su' | times_part: '12:00-14:30,18:00-22:30'
# Before cleanup - days_part: 'Sat' | times_part: '17:30-22:30'
# Before cleanup - days_part: 'We-Sat' | times_part: '20:00-24:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '00:00-02:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '14:30-19:00'
# Before cleanup - days_part: 'Su' | times_part: '14:30-18:00'
# Before cleanup - days_part: 'Mon,Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Sat-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '17:00-22:00+'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '12:00-13:30'
# Before cleanup - days_part: 'Mon-Th 16:00-22:00 || "Selbstabholung ab' | times_part: '12:00-22:00"'
# Before cleanup - days_part: 'Fri-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '12:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon - Sun: 12:00 - 15:00 Uhr und 17:00 - 22:00' | times_part: 'Uhr'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '08:00-22:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '13:30-18:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '12:00-21:30'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Tu-Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-16:00'
# Before cleanup - days_part: 'Su' | times_part: '09:00-14:30'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu-Su' | times_part: '17:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '13:00-21:00'
# Before cleanup - days_part: 'We-Sun' | times_part: '17:30-'
# Before cleanup - days_part: 'Mon-Sat 09:00-18:00, Su' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '11:00-02:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '12:00-16:00'
# Before cleanup - days_part: 'Fri' | times_part: '12:00-14:30'
# Before cleanup - days_part: 'Mon,We-Fri 12:00-14:30,16:30-22:00, Fri,Sat 12:00-14:30,16:30-22:30, Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Mon-Th 12:00-15:00,16:30-21:00, Fri 12:00-15:00,16:30-24:00, Sat 13:00-24:00, Su' | times_part: '13:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '10:00-14:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '07:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '07:30-17:30'
# Before cleanup - days_part: 'Su' | times_part: '08:00-17:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '12:00-14:30,17:30-22:30'
# Before cleanup - days_part: 'Sat-Sun' | times_part: '17:00-22:30'
# Before cleanup - days_part: 'Su-Th 11:00-23:00, Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'We-Mon' | times_part: '17:30-23:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-22:30'
# Before cleanup - days_part: 'Sat-Su' | times_part: '12:00-22:30'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Su-Th' | times_part: '11:00-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-18:30'
# Before cleanup - days_part: 'Sat' | times_part: '06:00-14:00'
# Before cleanup - days_part: 'Su' | times_part: '07:30-14:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Th-Sat' | times_part: '18:00-24:00'
# Before cleanup - days_part: 'Su-Mon off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '09:30-21:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:00-21:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-18:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '09:30-18:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00-23:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Su' | times_part: '07:00-16:30'
# Before cleanup - days_part: 'Mon,We-Fri' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Su-Fri' | times_part: '07:00-16:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '09:00-22:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-21:30'
# Before cleanup - days_part: 'Su' | times_part: '16:30-21:30'
# Before cleanup - days_part: 'Su-Th' | times_part: '11:30-21:00'
# Before cleanup - days_part: 'Fri-Sat' | times_part: '11:30-22:00'
# Before cleanup - days_part: 'Tu' | times_part: '11:00-19:00'
# Before cleanup - days_part: 'Tu-Fri' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Sat' | times_part: '09:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '09:30-14:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '11:00-21:30'
# Before cleanup - days_part: 'Fri' | times_part: '11:00-22:30'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-22:30'
# Before cleanup - days_part: 'Su' | times_part: '10:00-21:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:30-18:00'
# Before cleanup - days_part: 'Su,  off' | times_part: ''
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '07:00-16:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '13:30-20:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:30-20:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-19:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-20:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Apr off' | times_part: ''
# Before cleanup - days_part: 'Mon-Th' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '17:00-23:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-00:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '10:00-19:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-19:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-18:00'
# Before cleanup - days_part: '12' | times_part: '00-22:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-15:00'
# Before cleanup - days_part: 'Mon-Th 10:00-24:00, Fri,Sat 10:00-01:00, Su' | times_part: '10:00-24:00'
# Before cleanup - days_part: 'Su-Th 09:00-02:00, Fri,Sat' | times_part: '09:00-06:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00+'
# Before cleanup - days_part: 'May-Sep: Mon-Fri 15:00-21:30, Sat-Su' | times_part: '11:00-14:30,17:30-21:00'
# Before cleanup - days_part: 'Oct-Apr: Mon-Sat 17:00-21:30, Su' | times_part: '11:00-14:30,17:30-21:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-14:00,17:00-24:00'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Tu-Sat' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-21:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-00:00'
# Before cleanup - days_part: 'Tu-Th' | times_part: '12:00-14:00'
# Before cleanup - days_part: 'Fri-Su' | times_part: '12:00-18:00+'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-14:30,17:30-22:30'
# Before cleanup - days_part: 'Tu off' | times_part: ''
# Before cleanup - days_part: 'Su,Ph' | times_part: '00:00-24:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '17:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-14:30,17:00-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '12:00-22:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '09:00-18:00'
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu' | times_part: '11:30-15:00'
# Before cleanup - days_part: 'We-Sat' | times_part: '11:30-15:00,17:30-22:00'
# Before cleanup - days_part: 'Su' | times_part: '11:00-22:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Su-Th 11:00-24:00, Fri,Sat' | times_part: '11:00-01:00'
# Before cleanup - days_part: 'Su-Th 17:00-01:00, Fri-Sat' | times_part: '17:00-02:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:30-24:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '12:00-01:00'
# Before cleanup - days_part: 'Tu-Sat' | times_part: '17:00+'
# Before cleanup - days_part: 'Su' | times_part: '15:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:30-20:00'
# Before cleanup - days_part: 'Sat' | times_part: '11:30-18:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:30-15:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-14:00,17:00-24:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '12:00-00:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '20:00-18:00+'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '10:00+'
# Before cleanup - days_part: 'Sat-Su' | times_part: '11:00+'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '08:00-19:30'
# Before cleanup - days_part: 'Sat' | times_part: '08:30-20:00'
# Before cleanup - days_part: 'Su off' | times_part: ''
# Before cleanup - days_part: '11' | times_part: '00-18:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:00-20:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '11:00-14:00,17:30-24:00'
# Before cleanup - days_part: 'Sat' | times_part: '17:00-24:00'
# Before cleanup - days_part: 'Su' | times_part: '11:30-14:00,17:00-24:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '17:30-24:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '09:30-21:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '09:30-21:30'
# Before cleanup - days_part: 'Su' | times_part: '10:00-20:00'
# Before cleanup - days_part: 'Tu-Su' | times_part: '18:00-22:00'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '09:00-22:00'
# Before cleanup - days_part: 'Su' | times_part: '10:00-20:00'
# Before cleanup - days_part: 'off' | times_part: ''
# Before cleanup - days_part: 'Su-Th 11:00-22:30, Fri,Sat' | times_part: '11:00-24:00'
# Before cleanup - days_part: 'Mon' | times_part: '00:00-01:00,07:00-01:00'
# Before cleanup - days_part: 'Tu' | times_part: '07:00-21:30'
# Before cleanup - days_part: 'We-Th' | times_part: '07:00-01:00'
# Before cleanup - days_part: 'Fri' | times_part: '07:00-24:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '00:00-24:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Su' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '08:30-22:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '10:00-21:00'
# Before cleanup - days_part: 'Mon-Fri' | times_part: '06:00-20:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'Mon-Su' | times_part: '11:00-21:00'
# Before cleanup - days_part: '24/7' | times_part: ''
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-24:00'
# Before cleanup - days_part: 'Su' | times_part: '12:00-23:00'
# Before cleanup - days_part: 'Mon-Th' | times_part: '11:30-23:00'
# Before cleanup - days_part: 'Fri,Sat' | times_part: '11:30-24:00'
# Before cleanup - days_part: 'Su' | times_part: '09:00-22:30'
# Before cleanup - days_part: 'Mon-Sat' | times_part: '11:30-19:00'

# %%
#Add Toiletten
toiletten=gpd.read_file('toiletten-mit-oz.geojson')
columns_to_show=['Name','Barrierefrei','Öffnungszeiten']
for idx, row in toiletten.iterrows():
    if row.geometry and pd.notnull(row.geometry):
        lon, lat = row.geometry.x, row.geometry.y
        
        popup_lines = []
        # Manually add name first if it exists
        if 'Name' in row and pd.notnull(row['Name']):
            popup_lines.append(f"<b>Name:</b> {row['Name']}")

        bfree = []
        if 'Barrierefrei' in row and pd.notnull(row['Barrierefrei']):
            popup_lines.append(f"<b>Barrierefrei:</b> {row['Barrierefrei']}")
        

        # Create address from street and housenumber
        address = ""
        if 'addr:street' in row and pd.notnull(row['addr:street']):
            address += row['addr:street']
        if 'addr:housenumber' in row and pd.notnull(row['addr:housenumber']):
            address += f" {row['addr:housenumber']}"
        if address:
            popup_lines.append(f"<b>Address:</b> {address.strip()}")

        # Add other details, excluding ones already handled
        other_cols = ['Öffnungszeiten']
        for col in other_cols:
            if col in row and pd.notnull(row[col]):
                display_name = col.replace('_', ' ').replace(':', ' ').title()
                # Make website URL clickable
                if col == 'website' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>{display_name}:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                elif col =='Öffnungszeiten':
                    formatted_hours= format_opening_hours(row[col])
                    popup_lines.append(f"<b>{display_name}:</b><br>{formatted_hours}")
                else:
                    popup_lines.append(f"<b>{display_name}:</b> {row[col]}")

        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='gray', icon='restroom', prefix='fa')
            ).add_to(toiletten_cluster)
# Out:
# Before cleanup - days_part: 'Monntag 07:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Tueenstag 07:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Wedttwoch 07:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Thunnerstag 07:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Frieitag 07:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Satmstag 07:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Sonntag 09:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Monntag' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Satmstag' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Sonntag' | times_part: '09:00-21:00'
# Before cleanup - days_part: 'Monntag' | times_part: ''
# Before cleanup - days_part: 'Tueenstag' | times_part: ''
# Before cleanup - days_part: 'Wedttwoch 05:00 -' | times_part: '16:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: ''
# Before cleanup - days_part: 'Frieitag' | times_part: ''
# Before cleanup - days_part: 'Satmstag 05:00 -' | times_part: '16:00'
# Before cleanup - days_part: 'Sonntag' | times_part: ''
# Before cleanup - days_part: 'Monntag 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Tueenstag 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Wedttwoch 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Thunnerstag 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Frieitag 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Satmstag 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Sonntag 10:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Monntag 10:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Tueenstag 10:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Wedttwoch 10:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Thunnerstag 10:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Frieitag 10:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Satmstag 10:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Sonntag' | times_part: ''
# Before cleanup - days_part: 'Monntag' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '06:00-18:00'
# Before cleanup - days_part: 'Satmstag' | times_part: ''
# Before cleanup - days_part: 'Sonntag' | times_part: ''
# Before cleanup - days_part: 'Monntag 9:00 -' | times_part: '18:30'
# Before cleanup - days_part: 'Tueenstag 9:00 -' | times_part: '18:30'
# Before cleanup - days_part: 'Wedttwoch 9:00 -' | times_part: '18:30'
# Before cleanup - days_part: 'Thunnerstag 9:00 -' | times_part: '18:30'
# Before cleanup - days_part: 'Frieitag 9:00 -' | times_part: '18:30'
# Before cleanup - days_part: 'Satmstag -' | times_part: ''
# Before cleanup - days_part: 'Sonntag 14:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Monntag 17:00 -' | times_part: '22:30'
# Before cleanup - days_part: 'Tueenstag 17:00 -' | times_part: '22:30'
# Before cleanup - days_part: 'Wedttwoch -' | times_part: ''
# Before cleanup - days_part: 'Thunnerstag 17:00 -' | times_part: '22:30'
# Before cleanup - days_part: 'Frieitag 17:00 -' | times_part: '22:30'
# Before cleanup - days_part: 'Satmstag 17:00 -' | times_part: '22:30'
# Before cleanup - days_part: 'Sonntag 12:00 -' | times_part: '14:30'
# Before cleanup - days_part: 'Monntag 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Tueenstag 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Wedttwoch 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Thunnerstag 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Frieitag 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Satmstag 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Sonntag 10:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Monntag 8:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Tueenstag 8:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Wedttwoch 8:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Thunnerstag 8:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Frieitag 8:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Satmstag 8:00 -' | times_part: '14:00'
# Before cleanup - days_part: 'Sonntag -' | times_part: ''
# Before cleanup - days_part: 'Monntag 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Tueenstag 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Wedttwoch 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Thunnerstag 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Frieitag 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Satmstag 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Sonntag 0:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Monntag' | times_part: ''
# Before cleanup - days_part: 'Tueenstag' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Satmstag' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Sonntag' | times_part: '10:00-18:00'
# Before cleanup - days_part: 'Monntag' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '07:30-20:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '08:00-20:00'
# Before cleanup - days_part: 'Satmstag' | times_part: '07:30-20:00'
# Before cleanup - days_part: 'Sonntag' | times_part: ''
# Before cleanup - days_part: 'Monntag' | times_part: '17:0000:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '17:0001:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '17:0001:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '17:0001:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '17:0003:00'
# Before cleanup - days_part: 'Satmstag' | times_part: '17:0003:00'
# Before cleanup - days_part: 'Sonntag' | times_part: '17:0000:00'
# Before cleanup - days_part: 'Monntag' | times_part: '10:0023:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '10:0023:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '10:0023:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '10:0023:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '10:0000:00'
# Before cleanup - days_part: 'Satmstag' | times_part: '10:0000:00'
# Before cleanup - days_part: 'Sonntag' | times_part: '12:0018:00'
# Before cleanup - days_part: 'Monntag 7:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Tueenstag 7:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Wedttwoch 7:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Thunnerstag 7:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Frieitag 7:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Satmstag 7:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Sonntag -' | times_part: ''
# Before cleanup - days_part: 'Monntag -' | times_part: ''
# Before cleanup - days_part: 'Tueenstag 17:00 -' | times_part: '22:00'
# Before cleanup - days_part: 'Wedttwoch 17:00 -' | times_part: '22:00'
# Before cleanup - days_part: 'Thunnerstag 17:00 -' | times_part: '22:00'
# Before cleanup - days_part: 'Frieitag 17:00 -' | times_part: '22:00'
# Before cleanup - days_part: 'Satmstag 17:00 -' | times_part: '22:00'
# Before cleanup - days_part: 'Sonntag 12:00 - 14:00, 17:00 -' | times_part: '22:00'
# Before cleanup - days_part: 'Monntag 8:00 - 12:00, 14:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Tueenstag 8:00 -' | times_part: '12:00'
# Before cleanup - days_part: 'Wedttwoch 8:00 -' | times_part: '12:00'
# Before cleanup - days_part: 'Thunnerstag 8:00 - 12:00, 14:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Frieitag 8:00 -' | times_part: '12:00'
# Before cleanup - days_part: 'Satmstag -' | times_part: ''
# Before cleanup - days_part: 'Sonntag -' | times_part: ''
# Before cleanup - days_part: 'Monntag 9:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Tueenstag 9:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Wedttwoch 9:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Thunnerstag 9:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Frieitag 9:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Satmstag 9:00 -' | times_part: '14:00'
# Before cleanup - days_part: 'Sonntag -' | times_part: ''
# Before cleanup - days_part: 'Monntag 7:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Tueenstag 7:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Wedttwoch 7:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Thunnerstag 7:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Frieitag 7:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Satmstag 7:00 -' | times_part: '17:00'
# Before cleanup - days_part: 'Sonntag 8:00 -' | times_part: '17:00'
# Before cleanup - days_part: 'Monntag 6:30 -' | times_part: '18:00'
# Before cleanup - days_part: 'Tueenstag 6:30 -' | times_part: '18:00'
# Before cleanup - days_part: 'Wedttwoch 6:30 -' | times_part: '18:00'
# Before cleanup - days_part: 'Thunnerstag 6:30 -' | times_part: '18:00'
# Before cleanup - days_part: 'Frieitag 6:30 -' | times_part: '18:00'
# Before cleanup - days_part: 'Satmstag 6:30 -' | times_part: '13:00'
# Before cleanup - days_part: 'Sonntag 7:30 -' | times_part: '16:30'
# Before cleanup - days_part: 'Monntag' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Satmstag' | times_part: '08:00-18:00'
# Before cleanup - days_part: 'Sonntag -' | times_part: ''
# Before cleanup - days_part: 'Monntag' | times_part: '15:00-01:00'
# Before cleanup - days_part: 'Tueenstag' | times_part: '15:00-01:00'
# Before cleanup - days_part: 'Wedttwoch' | times_part: '15:00-01:00'
# Before cleanup - days_part: 'Thunnerstag' | times_part: '15:00-03:00'
# Before cleanup - days_part: 'Frieitag' | times_part: '15:00-03:00'
# Before cleanup - days_part: 'Satmstag' | times_part: ''
# Before cleanup - days_part: 'Sonntag' | times_part: ''
# Before cleanup - days_part: 'Monntag 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Tueenstag 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Wedttwoch 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Thunnerstag 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Frieitag 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Satmstag 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Sonntag 00:00 -' | times_part: '24:00'
# Before cleanup - days_part: 'Monntag 15:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Tueenstag 15:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Wedttwoch 15:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Thunnerstag 15:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Frieitag 15:00 -' | times_part: '19:00'
# Before cleanup - days_part: 'Satmstag -' | times_part: ''
# Before cleanup - days_part: 'Sonntag 15:00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Monntag 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Tueenstag 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Wedttwoch 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Thunnerstag 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Frieitag 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Satmstag 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Sonntag 11:00 - 14:30, 17:00 -' | times_part: '21:00'
# Before cleanup - days_part: 'Monntag' | times_part: ''
# Before cleanup - days_part: 'Tueenstag' | times_part: ''
# Before cleanup - days_part: 'Wedttwoch' | times_part: ''
# Before cleanup - days_part: 'Thunnerstag' | times_part: ''
# Before cleanup - days_part: 'Frieitag' | times_part: ''
# Before cleanup - days_part: 'Satmstag' | times_part: ''
# Before cleanup - days_part: 'Sonntag' | times_part: ''
# Before cleanup - days_part: 'Monntag 10.00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Tueenstag 10.00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Wedttwoch 10.00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Thunnerstag 10.00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Frieitag 10.00 -' | times_part: '18:00'
# Before cleanup - days_part: 'Satmstag -' | times_part: ''
# Before cleanup - days_part: 'Sonntag -' | times_part: ''

# %%
#Add Bäder 
baeder=gpd.read_file('baeder.geojson')
columns_to_show=['NAME','addr:street','addr:housenumber','contact:phone','opening_hours','LINK1']
for idx, row in baeder.iterrows():
    if row.geometry and pd.notnull(row.geometry):
        lon, lat = row.geometry.x, row.geometry.y
        
        popup_lines = []
        # Manually add name first if it exists
        if 'NAME' in row and pd.notnull(row['NAME']):
            popup_lines.append(f"<b>Name:</b> {row['NAME']}")

        # Create address from street and housenumber
        address = ""
        if 'addr:street' in row and pd.notnull(row['addr:street']):
            address += row['addr:street']
        if 'addr:housenumber' in row and pd.notnull(row['addr:housenumber']):
            address += f" {row['addr:housenumber']}"
        if address:
            popup_lines.append(f"<b>Address:</b> {address.strip()}")

        # Add other details, excluding ones already handled
        other_cols = ['contact:phone', 'opening_hours', 'LINK1']
        for col in other_cols:
            if col in row and pd.notnull(row[col]):
                display_name = col.replace('_', ' ').replace(':', ' ').title()
                # Make website URL clickable
                if col == 'LINK1' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>Homepage:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                elif col =='opening_hours':
                    formatted_hours= format_opening_hours(row[col])
                    popup_lines.append(f"<b>{display_name}:</b><br>{formatted_hours}")
                else:
                    popup_lines.append(f"<b>{display_name}:</b> {row[col]}")

        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='lightblue', icon='swimming-pool', prefix='fa')
            ).add_to(baeder_cluster)
# Out:
# Before cleanup - days_part: 'Mon off' | times_part: ''
# Before cleanup - days_part: 'Tu' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'We off' | times_part: ''
# Before cleanup - days_part: 'Th' | times_part: '06:30-22:00'
# Before cleanup - days_part: 'Fri' | times_part: '10:00-22:00'
# Before cleanup - days_part: 'Sat' | times_part: '10:00-17:00'
# Before cleanup - days_part: 'Su' | times_part: '09:00-16:00'
# Before cleanup - days_part: 'Su 08:00-18:00, Mon,Th,Fri 06:30-08:00, Mon,Fri 15:00-17:00, Sat' | times_part: '07:00-17:00'
# Before cleanup - days_part: 'Mon,Tu,Th,Fri' | times_part: '07:00-20:00'
# Before cleanup - days_part: 'We' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Sat,Su' | times_part: '09:00-20:00'
# Before cleanup - days_part: 'Oct-Apr off' | times_part: ''
# Before cleanup - days_part: '2025 May 01' | times_part: '12:00-20:00'
# Before cleanup - days_part: 'Mon' | times_part: '06:30-09:00,16:00-18:00'
# Before cleanup - days_part: 'Tu,Th' | times_part: '06:30-08:00'
# Before cleanup - days_part: 'We' | times_part: '15:00-21:00'
# Before cleanup - days_part: 'Fri' | times_part: '06:30-08:00,15:00-21:00'
# Before cleanup - days_part: 'Sat,Su,Ph off' | times_part: ''

# %%
#Add Theater 
theater=gpd.read_file('theater.geojson')
columns_to_show=['NAME','STR_NAME','HSNR','PLZ']
for idx, row in theater.iterrows():
    if row.geometry and pd.notnull(row.geometry):
        lon, lat = row.geometry.x, row.geometry.y
        
        popup_lines = []
        # Manually add name first if it exists
        if 'NAME' in row and pd.notnull(row['NAME']):
            popup_lines.append(f"<b>Name:</b> {row['NAME']}")

        # Create address from street and housenumber
        address = ""
        if 'STR_NAME' in row and pd.notnull(row['STR_NAME']):
            address += row['STR_NAME']
        if 'HSNR' in row and pd.notnull(row['HSNR']):
            address += f" {row['HSNR']}"
        if 'PLZ' in row and pd.notnull(row['PLZ']):
            address += f" {row['PLZ']}"
        if address:
            popup_lines.append(f"<b>Addresse:</b> {address.strip()}")

        # Add other details, excluding ones already handled
        other_cols = ['contact:phone', 'opening_hours', 'HOMEPAGE']
        for col in other_cols:
            if col in row and pd.notnull(row[col]):
                display_name = col.replace('_', ' ').replace(':', ' ').title()
                # Make website URL clickable
                if col == 'HOMEPAGE' and 'http' in str(row[col]):
                    popup_lines.append(f"<b>Homepage:</b> <a href='{row[col]}' target='_blank'>{row[col]}</a>")
                elif col =='opening_hours':
                    formatted_hours= format_opening_hours(row[col])
                    popup_lines.append(f"<b>{display_name}:</b><br>{formatted_hours}")
                else:
                    popup_lines.append(f"<b>{display_name}:</b> {row[col]}")

        if popup_lines:  # Only add marker if there's something to show
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup("<br>".join(popup_lines), max_width=300),
                icon=folium.Icon(color='darkpurple', icon='theater-masks', prefix='fa')
            ).add_to(theater_cluster)

# %% [markdown]
# Add Grünflächen

# %%
gruenflaechen = gpd.read_file('gruenflaechen.geojson')

# %%
# Convert any timestamp columns to strings
for col in gruenflaechen.select_dtypes(include=['datetime64']).columns:
    gruenflaechen[col] = gruenflaechen[col].astype(str)

# %%
# Define a style function for the green areas
def style_function(feature):
    return {
        'fillColor': '#78c679',  # Light green fill
        'color': '#2ca25f',      # Darker green border
        'weight': 1,
        'fillOpacity': 0.7,
        'opacity': 0.8
    }

# %%
# Add the GeoJSON to the map
folium.GeoJson(
    gruenflaechen,
    name='Grünflächen',
    style_function=style_function,
    tooltip=folium.GeoJsonTooltip(
        fields=['name'],  # Only show name,
        aliases=[''],
        localize=True,
        sticky=True,      # Makes the tooltip stay visible
        style="""
            font-size: 14px;
            background-color: #F0EFEF;
            border: 1px solid #2ca25f;
            border-radius: 3px;
            padding: 5px;
        """
    )
).add_to(gruenflaechen_group)

# %%
print(f"Successfully added {len(gruenflaechen)} green areas to the map")
# Out:
# Successfully added 5043 green areas to the map

# %%
# Add all feature groups to the map
for group in [museen_group, buechereien_group, sportstaetten_group, tischtennis_group,
              wickelplaetze_group, give_boxen_group, kinos_group, kinder_group,
              friedhof_group, refill_group, gastro_group, toiletten_group, baeder_group, theater_group, gruenflaechen_group]:
    group.add_to(muenster)

# %%
# Add layer control (only need to do this once after all layers are added)
folium.LayerControl().add_to(muenster)

# %%
# Go back to original directory and save map 
os.chdir(original_dir)
muenster.save("muenster_map.html")
